# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,r2_score

# %%
place_df = pd.read_csv("D:\\A_WORK_DATA\\Navttc DataSET\\placement.csv")
place_df.head()
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %%
plt.figure(figsize=(10, 6))  # Set figure size
plt.plot(place_df['cgpa'],place_df['package'],color = 'Blue', marker= 'o',markeredgecolor='red',label='Placement Based on GPA',
        linestyle='--',linewidth=2)
plt.title('Placement Based on GPA')
plt.ylabel('GPA')
plt.xlabel('Package')
plt.legend()
plt.show()

# %%
plt.
